# %%
import wgertrainer

# %%
# !pip list
# Out:
# Package                       Version      Editable project location
# ----------------------------- ------------ ----------------------------------------------------
# alabaster                     0.7.13
# anyascii                      0.3.2
# anyio                         4.1.0
# appnope                       0.1.3
# argon2-cffi                   23.1.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.3.0
# astroid                       3.0.1
# asttokens                     2.4.1
# async-lru                     2.0.4
# attrs                         23.1.0
# Babel                         2.13.1
# beautifulsoup4                4.12.2
# bleach                        6.1.0
# certifi                       2023.11.17
# cffi                          1.16.0
# charset-normalizer            3.3.2
# click                         8.1.7
# comm                          0.2.0
# debugpy                       1.8.0
# decorator                     5.1.1
# ...

# %%
import sys
print(sys.path)
# Out:
# ['/Users/shuaitaotan/Tan_Shuaitao_homework/wgertrainer/src/wgertrainer', '/Library/Frameworks/Python.framework/Versions/3.11/lib/python311.zip', '/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11', '/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/lib-dynload', '', '/Users/shuaitaotan/Library/Caches/pypoetry/virtualenvs/wgertrainer-x-Pc0AlW-py3.11/lib/python3.11/site-packages', '/Users/shuaitaotan/Tan_Shuaitao_homework/wgertrainer/src', '/Users/shuaitaotan/Tan_Shuaitao_homework/wgertrainer', '/Users/shuaitaotan/Tan_Shuaitao_homework/wgertrainer', '/Users/shuaitaotan/Tan_Shuaitao_homework/wgertrainer/src/wgertrainer', '/Users/shuaitaotan/Tan_Shuaitao_homework/wgertrainer/src/wgertrainer']

# %%
import sys
sys.path.append('/Users/shuaitaotan/Tan_Shuaitao_homework/wgertrainer')

# %%
import importlib.util
spec = importlib.util.spec_from_file_location("display_equipment_table", "/Users/shuaitaotan/Tan_Shuaitao_homework/wgertrainer/src/wgertrainer/display_equipment_table.py")
display_equipment_table = importlib.util.module_from_spec(spec)
spec.loader.exec_module(display_equipment_table)

# Use the function
display_equipment_table.display_equipment_table()
# Out:
#                Equipment Name  Equipment ID
# 0                     Barbell             1
# 1                      SZ-Bar             2
# 2                    Dumbbell             3
# 3                     Gym mat             4
# 4                  Swiss Ball             5
# 5                 Pull-up bar             6
# 6  none (bodyweight exercise)             7
# 7                       Bench             8
# 8               Incline bench             9
# 9                  Kettlebell            10
#                Equipment Name  Equipment ID
# 0                     Barbell             1
# 1                      SZ-Bar             2
# 2                    Dumbbell             3
# 3                     Gym mat             4
# 4                  Swiss Ball             5
# 5                 Pull-up bar             6
# 6  none (bodyweight exercise)             7
# 7                       Bench             8
# 8               Incline bench             9
# ...

# %%
import importlib.util

# Define the full path to the module
module_path = "/Users/shuaitaotan/Tan_Shuaitao_homework/wgertrainer/src/wgertrainer/display_muscle_table.py"

# Define the module name (you can choose any valid module name)
module_name = "custom_display_muscle_table"

# Create a module object from the file
spec = importlib.util.spec_from_file_location(module_name, module_path)
custom_display_muscle_table = importlib.util.module_from_spec(spec)
spec.loader.exec_module(custom_display_muscle_table)

# Now you can use the function from the module
custom_display_muscle_table.display_muscle_table()
# Out:
#  id                        name    name_en
#   1              Biceps brachii     Biceps
#   2            Anterior deltoid  Shoulders
#   3           Serratus anterior      Chest
#   4            Pectoralis major      Chest
#   5             Triceps brachii    Triceps
#   6            Rectus abdominis        Abs
#   7               Gastrocnemius     Calves
#   8             Gluteus maximus     Glutes
#   9                   Trapezius       Back
#  10          Quadriceps femoris      Quads
#  11              Biceps femoris Hamstrings
#  12            Latissimus dorsi       Lats
#  13                  Brachialis        Arm
#  14 Obliquus externus abdominis        Abs
#  15                      Soleus      Ankle
#  id                        name    name_en
#   1              Biceps brachii     Biceps
#   2            Anterior deltoid  Shoulders
#   3           Serratus anterior      Chest
#   4            Pectoralis major      Chest
#   5             Triceps brachii    Triceps
# ...
